# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/aniket/github/Exceptional_Model_Mining_2AMM20/pipeline_v2/dataset_with_residuals/year_prediction_msd_with_residuals.csv")
df
# Out:
#         target  timbre_avg_1  timbre_avg_2  timbre_avg_3  timbre_avg_4  \
# 0         2001      49.94357      21.47114      73.07750       8.74861
# 1         2001      48.73215      18.42930      70.32679      12.94636
# 2         2001      50.95714      31.85602      55.81851      13.41693
# 3         2001      48.24750      -1.89837      36.29772       2.58776
# 4         2001      50.97020      42.20998      67.09964       8.46791
# ...        ...           ...           ...           ...           ...
# 515340    2006      51.28467      45.88068      22.19582      -5.53319
# 515341    2006      49.87870      37.93125      18.65987      -3.63581
# 515342    2006      45.12852      12.65758     -38.72018       8.80882
# 515343    2006      44.16614      32.38368      -3.34971      -2.49165
# 515344    2005      51.85726      59.11655      26.39436      -5.46030
#
#         timbre_avg_5  timbre_avg_6  timbre_avg_7  timbre_avg_8  timbre_avg_9  \
# ...

# %%
df["target"].dtype
# Out:
# dtype('int64')

# %%
df["timbre_avg_1"].dtype
# Out:
# dtype('float64')

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515345 entries, 0 to 515344
# Data columns (total 94 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   target            515345 non-null  int64
#  1   timbre_avg_1      515345 non-null  float64
#  2   timbre_avg_2      515345 non-null  float64
#  3   timbre_avg_3      515345 non-null  float64
#  4   timbre_avg_4      515345 non-null  float64
#  5   timbre_avg_5      515345 non-null  float64
#  6   timbre_avg_6      515345 non-null  float64
#  7   timbre_avg_7      515345 non-null  float64
#  8   timbre_avg_8      515345 non-null  float64
#  9   timbre_avg_9      515345 non-null  float64
#  10  timbre_avg_10     515345 non-null  float64
#  11  timbre_avg_11     515345 non-null  float64
#  12  timbre_avg_12     515345 non-null  float64
#  13  timbre_cov_1_1    515345 non-null  float64
#  14  timbre_cov_1_2    515345 non-null  float64
# ...

# %%
df['target'] = df['target'].astype(np.int16)

timbre_cols = [c for c in df.columns if c.startswith('timbre_')]
df[timbre_cols] = df[timbre_cols].astype(np.float32)

# %%
df.info(memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 515345 entries, 0 to 515344
# Data columns (total 94 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   target            515345 non-null  int16
#  1   timbre_avg_1      515345 non-null  float32
#  2   timbre_avg_2      515345 non-null  float32
#  3   timbre_avg_3      515345 non-null  float32
#  4   timbre_avg_4      515345 non-null  float32
#  5   timbre_avg_5      515345 non-null  float32
#  6   timbre_avg_6      515345 non-null  float32
#  7   timbre_avg_7      515345 non-null  float32
#  8   timbre_avg_8      515345 non-null  float32
#  9   timbre_avg_9      515345 non-null  float32
#  10  timbre_avg_10     515345 non-null  float32
#  11  timbre_avg_11     515345 non-null  float32
#  12  timbre_avg_12     515345 non-null  float32
#  13  timbre_cov_1_1    515345 non-null  float32
#  14  timbre_cov_1_2    515345 non-null  float32
# ...

# %%
df.to_csv("/Users/aniket/github/Exceptional_Model_Mining_2AMM20/pipeline_v2/dataset_with_residuals/updated_year_prediction_msd_with_residuals.csv")
